# %%
import sys
import os

sys.path.append(os.path.abspath(".."))  # raíz del proyecto
sys.path.append(os.path.abspath("../.secrets"))

from etl import etl_bronze

etl_bronze.main()
# Out:
# ✅ Pipeline ejecutado correctamente
